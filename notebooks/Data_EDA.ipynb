# %%
import torch
import numpy as np
import pandas as pd
import pydicom as dic
import os
import glob
import matplotlib.pyplot as plt

# %%
DATA_PATH = '/Datasets/SIIM-COVID19'

# %%
os.listdir(DATA_PATH) #Location Has train and test
# Out:
# ['sample_submission.csv',
#  'test',
#  'train_image_level.csv',
#  'train_study_level.csv',
#  'train',
#  'siim-covid19-detection.zip']

# %%
img_train_path = glob.glob(DATA_PATH + "/train/*/*/*.dcm")

# %%
samp1 = dic.dcmread(img_train_path[0])

# %%
plt.imshow(samp1.pixel_array)

# %%
train_img = pd.read_csv(DATA_PATH+'/train_image_level.csv')

# %%
train_img[train_img.id == ]
# Out:
#                       id                                              boxes  \
# 0     000a312787f2_image  [{'x': 789.28836, 'y': 582.43035, 'width': 102...
# 1     000c3a3f293f_image                                                NaN
# 2     0012ff7358bc_image  [{'x': 677.42216, 'y': 197.97662, 'width': 867...
# 3     001398f4ff4f_image  [{'x': 2729, 'y': 2181.33331, 'width': 948.000...
# 4     001bd15d1891_image  [{'x': 623.23328, 'y': 1050, 'width': 714, 'he...
# ...                  ...                                                ...
# 6329  ffcc6edd9445_image                                                NaN
# 6330  ffd91a2c4ca0_image                                                NaN
# 6331  ffd9b6cf2961_image  [{'x': 2197.38566, 'y': 841.07361, 'width': 31...
# 6332  ffdc682f7680_image  [{'x': 2729.27083, 'y': 332.26044, 'width': 14...
# 6333  ffe942c8655f_image  [{'x': 208.86463, 'y': 91.53448, 'width': 450....
#
# ...

# %%
img_train_path[0][-16:-4]
# Out:
# '7c1b82387e6c'

# %%
img_train_path[0]
# Out:
# '/Datasets/SIIM-COVID19/train/7c96d6d546d3/e480ca8e0a91/7c1b82387e6c.dcm'
